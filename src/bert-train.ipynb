# %% [markdown]
# BERT to run Squad2.0

# %%
pip install --upgrade pip

# %%
# !git clone https://github.com/huggingface/transformers

# %%
cd transformers

# %%
pip install .

# %%
cd /content

# %%
# !wget -O train-v2.0.json https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# !wget -O dev-v2.0.json https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json

# %%
import pandas as pd

train = pd.read_csv("/content/drive/MyDrive/Yonsei/CS4-2/Sojong20Fall/Bert/train-v1.1.json")
print(train.head())

# %%
# !python /content/drive/MyDrive/Yonsei/CS4-2/Sojong20Fall/Bert/run_squad.py \
  --model_type bert \
  --model_name_or_path bert-base-uncased \
  --do_train \
  --do_eval \
  --do_lower_case \
  --train_file /content/drive/MyDrive/Yonsei/CS4-2/Sojong20Fall/Bert/train-v1.1.json \
  --predict_file /content/drive/MyDrive/Yonsei/CS4-2/Sojong20Fall/Bert/dev-v1.1.json \
  --per_gpu_train_batch_size 1 \
  --per_gpu_eval_batch_size 1 \
  --learning_rate 3e-5 \
  --num_train_epochs 1.0 \
  --max_seq_length 384 \
  --doc_stride 128 \
  --num_train_epochs 1 \
  --output_dir /content/drive/My\ Drive/Yonsei/CS4-2/Sojong20Fall/BertRes \
